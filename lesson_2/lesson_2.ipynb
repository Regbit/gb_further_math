# %% [markdown]
# ![title](lesson_2_1.jpg)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 6, 50)
y = (-17/8)*x**2 + (25/2)*x - 67/8
x1, y1 = 1, 2
fig, ax = plt.subplots()
ax.plot(x, y)
ax.plot(1, 2, 'yo')
ax.plot(3, 10, 'go')
ax.plot(5, 1, 'ro')

# %% [markdown]
# ![title](lesson_2_2.jpg)

# %% [markdown]
# ![title](lesson_2_3.jpg)

# %% [markdown]
# ![title](lesson_2_4.jpg)

# %% [markdown]
# ![title](lesson_2_5.jpg)
