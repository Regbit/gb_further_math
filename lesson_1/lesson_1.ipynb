# %% [markdown]
# ![title](lesson_1_1.png)

# %% [markdown]
# ![title](lesson_1_2.png)

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 300)
plt.plot(x, np.cos(1*x))
plt.plot(x, np.cos(3.1415*x))
